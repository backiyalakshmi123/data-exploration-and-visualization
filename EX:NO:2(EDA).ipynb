# %% [markdown]
# <a href="https://colab.research.google.com/github/backiyalakshmi123/data-exploration-and-visualization/blob/main/EX%3ANO%3A2(EDA).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample data
data = {
    'ProductID': [101, 102, 103, 104, 105],
    'ProductName': ['Pen', 'Notebook', 'Eraser', 'Pencil', 'Scale'],
    'Category': ['Stationery', 'Stationery', 'Stationery', 'Stationery', 'Stationery'],
    'Price': [10, 50, 5, 7, 15],
    'QuantitySold': [100, 60, 150, 130, 90]
}

# Create DataFrame
df = pd.DataFrame(data)
print("CSV file created successfully.")
print(df.info())

print("\nData columns (total {} columns):".format(len(df.columns)))
print(df.describe(include='all'))

# Plot: Distribution of Prices
plt.figure(figsize=(6, 4))
plt.hist(df['Price'], bins=5, color='skyblue', edgecolor='black')
plt.title('Distribution of Product Prices')
plt.xlabel('Price')
plt.ylabel('Count')
plt.grid(True)
plt.show()

# Plot: Top Selling Products
top_products = df.sort_values(by='QuantitySold', ascending=False).head(5)
plt.figure(figsize=(8, 4))
plt.bar(top_products['ProductName'], top_products['QuantitySold'], color='orange')
plt.title('Top Selling Products')
plt.xlabel('Product Name')
plt.ylabel('Quantity Sold')
plt.grid(axis='y')
plt.show()
# Out:
# CSV file created successfully.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ProductID     5 non-null      int64
#  1   ProductName   5 non-null      object
#  2   Category      5 non-null      object
#  3   Price         5 non-null      int64
#  4   QuantitySold  5 non-null      int64
# dtypes: int64(3), object(2)
# memory usage: 332.0+ bytes
# None
#
# Data columns (total 5 columns):
#          ProductID ProductName    Category      Price  QuantitySold
# count     5.000000           5           5   5.000000      5.000000
# unique         NaN           5           1        NaN           NaN
# top            NaN         Pen  Stationery        NaN           NaN
# freq           NaN           1           5        NaN           NaN
# mean    103.000000         NaN         NaN  17.400000    106.000000
# ...
